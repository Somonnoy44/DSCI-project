# %%
import gzip

def gunzip(source_filepath, dest_filepath, block_size=65536):
    with gzip.open(source_filepath, 'rb') as s_file, \
            open(dest_filepath, 'wb') as d_file:
        while True:
            block = s_file.read(block_size)
            if not block:
                break
            else:
                d_file.write(block)

# %%
import gzip
import shutil

def gunzip_shutil(source_filepath, dest_filepath, block_size=65536):
    with gzip.open(source_filepath, 'rb') as s_file, \
            open(dest_filepath, 'wb') as d_file:
        shutil.copyfileobj(s_file, d_file, block_size)

# %%
a_file = gzip.open("day_0.gz", "rb")
contents = a_file.read()

print(contents)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Input In [4], in <cell line: 2>()
#       1 a_file = gzip.open("day_0.gz", "rb")
# ----> 2 contents = a_file.read()
#       4 print(contents)
#
# File ~\anaconda3\lib\gzip.py:300, in GzipFile.read(self, size)
#     299     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 300 return self._buffer.read(size)
#
# File ~\anaconda3\lib\gzip.py:509, in _GzipReader.read(self, size)
#     506         raise EOFError("Compressed file ended before the "
#     507                        "end-of-stream marker was reached")
# --> 509 self._add_read_data( uncompress )
#     510 self._pos += len(uncompress)
#
# File ~\anaconda3\lib\gzip.py:514, in _GzipReader._add_read_data(self, data)
#     513 def _add_read_data(self, data):
# --> 514     self._crc = zlib.crc32(data, self._crc)
# ...

# %%
import gzip
import csv
with gzip.open('day_0.gz', 'rt') as f:

    tsv_reader = csv.reader(f, delimiter="\t")

    number_of_lines = 10

    for i in range(number_of_lines):
        row = next(tsv_reader)
        print(i, row)
# Out:
# 0 ['1', '5', '110', '', '16', '', '1', '0', '14', '7', '1', '', '306', '', '62770d79', 'e21f5d58', 'afea442f', '945c7fcf', '38b02748', '6fcd6dcb', '3580aa21', '28808903', '46dedfa6', '2e027dc1', '0c7c4231', '95981d1f', '00c5ffb7', 'be4ee537', '8a0b74cc', '4cdc3efa', 'd20856aa', 'b8170bba', '9512c20b', 'c38e2f28', '14f65a5d', '25b1b089', 'd7c1fc0b', '7caf609c', '30436bfc', 'ed10571d']
# 1 ['0', '32', '3', '5', '', '1', '0', '0', '61', '5', '0', '1', '3157', '5', 'e5f3fd8d', 'a0aaffa6', '6faa15d5', 'da8a3421', '3cd69f23', '6fcd6dcb', 'ab16ed81', '43426c29', '1df5e154', '7de9c0a9', '6652dc64', '99eb4e27', '00c5ffb7', 'be4ee537', 'f3bbfe99', '4cdc3efa', 'd20856aa', 'a1eb1511', '9512c20b', 'febfd863', 'a3323ca1', 'c8e1ee56', '1752e9e8', '75350c8a', '991321ea', 'b757e957']
# ...

# %%
import gzip
import csv
with gzip.open('day_0.gz', 'rt') as f:

    tsv_reader = csv.reader(f, delimiter="\t")

    number_of_lines = 100

    for i in range(number_of_lines):
        row = next(tsv_reader)
        print(i, row)
# Out:
# 0 ['1', '5', '110', '', '16', '', '1', '0', '14', '7', '1', '', '306', '', '62770d79', 'e21f5d58', 'afea442f', '945c7fcf', '38b02748', '6fcd6dcb', '3580aa21', '28808903', '46dedfa6', '2e027dc1', '0c7c4231', '95981d1f', '00c5ffb7', 'be4ee537', '8a0b74cc', '4cdc3efa', 'd20856aa', 'b8170bba', '9512c20b', 'c38e2f28', '14f65a5d', '25b1b089', 'd7c1fc0b', '7caf609c', '30436bfc', 'ed10571d']
# 1 ['0', '32', '3', '5', '', '1', '0', '0', '61', '5', '0', '1', '3157', '5', 'e5f3fd8d', 'a0aaffa6', '6faa15d5', 'da8a3421', '3cd69f23', '6fcd6dcb', 'ab16ed81', '43426c29', '1df5e154', '7de9c0a9', '6652dc64', '99eb4e27', '00c5ffb7', 'be4ee537', 'f3bbfe99', '4cdc3efa', 'd20856aa', 'a1eb1511', '9512c20b', 'febfd863', 'a3323ca1', 'c8e1ee56', '1752e9e8', '75350c8a', '991321ea', 'b757e957']
# ...

# %%
import pandas as pd
# df = pd.Dataframe(columns = ['Col 1','Col 2','Col 3','Col 4','Col 5','Col 6','Col 7','Col 8','Col 9','Col 10','Col 11','Col 12','Col 13','Col 14','Col 15','Col 16','Col 17','Col 18','Col 19','Col 20','Col 21','Col 22','Col 23','Col 24','Col 25','Col 26','Col 27','Col 28','Col 29','Col 30','Col 31','Col 32','Col 33','Col 34','Col 35','Col 36','Col 37','Col 38','Col 39','Col 40','Col 41'])

import gzip
import csv
with gzip.open('day_0.gz', 'rt') as f:

    tsv_reader = csv.reader(f, delimiter="\t")

    number_of_lines = 100

    for i in range(number_of_lines):
        row = next(tsv_reader)
        print(i, row)
        df.append(row)
# Out:
# 0 ['1', '5', '110', '', '16', '', '1', '0', '14', '7', '1', '', '306', '', '62770d79', 'e21f5d58', 'afea442f', '945c7fcf', '38b02748', '6fcd6dcb', '3580aa21', '28808903', '46dedfa6', '2e027dc1', '0c7c4231', '95981d1f', '00c5ffb7', 'be4ee537', '8a0b74cc', '4cdc3efa', 'd20856aa', 'b8170bba', '9512c20b', 'c38e2f28', '14f65a5d', '25b1b089', 'd7c1fc0b', '7caf609c', '30436bfc', 'ed10571d']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 6>()
#      13 row = next(tsv_reader)
#      14 print(i, row)
# ---> 15 df.append(row)
#
# NameError: name 'df' is not defined

# %%
import gzip
import csv
with gzip.open('day_0.gz', 'rt') as f:

    tsv_reader = csv.reader(f, delimiter="\t")

    number_of_lines = 100

    for i in range(number_of_lines):
        row = next(tsv_reader)
        for j in row:
            print(j)
# Out:
# 1
# 5
# 110
#
# 16
#
# 1
# 0
# 14
# 7
# 1
#
# 306
#
# 62770d79
# e21f5d58
# afea442f
# 945c7fcf
# 38b02748
# 6fcd6dcb
# 3580aa21
# 28808903
# 46dedfa6
# 2e027dc1
# 0c7c4231
# 95981d1f
# 00c5ffb7
# be4ee537
# 8a0b74cc
# 4cdc3efa
# d20856aa
# b8170bba
# 9512c20b
# c38e2f28
# 14f65a5d
# 25b1b089
# d7c1fc0b
# 7caf609c
# 30436bfc
# ed10571d
# 0
# 32
# 3
# 5
#
# 1
# 0
# 0
# 61
# 5
# 0
# 1
# 3157
# 5
# e5f3fd8d
# a0aaffa6
# 6faa15d5
# da8a3421
# 3cd69f23
# 6fcd6dcb
# ab16ed81
# 43426c29
# 1df5e154
# 7de9c0a9
# 6652dc64
# 99eb4e27
# 00c5ffb7
# be4ee537
# f3bbfe99
# 4cdc3efa
# d20856aa
# a1eb1511
# 9512c20b
# febfd863
# a3323ca1
# c8e1ee56
# 1752e9e8
# 75350c8a
# 991321ea
# b757e957
# 0
#
# 233
# 1
# 146
# 1
# 0
# 0
# 99
# 7
# 0
# 1
# 3101
# 1
# 62770d79
# ad984203
# 62bec60d
# 386c49ee
# e755064d
# 6fcd6dcb
# b5f5eb62
# d1f2cc8b
# 2e4e821f
# 2e027dc1
# 0c7c4231
# 12716184
# 00c5ffb7
# be4ee537
# f70f0d0b
# 4cdc3efa
# d20856aa
# 628f1b8d
# 9512c20b
# c38e2f28
# 14f65a5d
# 25b1b089
# d7c1fc0b
# ...

# %%
import gzip
import csv
import pandas as pd
list = []
with gzip.open('day_0.gz', 'rt') as f:

    tsv_reader = csv.reader(f, delimiter="\t")

    number_of_lines = 1000

    for i in range(number_of_lines):
        row = next(tsv_reader)
        list.append(row)
        df=pd.DataFrame(list,columns=['Col 1','Col 2','Col 3','Col 4','Col 5','Col 6','Col 7','Col 8','Col 9','Col 10','Col 11','Col 12','Col 13','Col 14','Col 15','Col 16','Col 17','Col 18','Col 19','Col 20','Col 21','Col 22','Col 23','Col 24','Col 25','Col 26','Col 27','Col 28','Col 29','Col 30','Col 31','Col 32','Col 33','Col 34','Col 35','Col 36','Col 37','Col 38','Col 39','Col 40'])
        for j in row:
            print(j)
            
print(df)
# Out:
# 1
# 5
# 110
#
# 16
#
# 1
# 0
# 14
# 7
# 1
#
# 306
#
# 62770d79
# e21f5d58
# afea442f
# 945c7fcf
# 38b02748
# 6fcd6dcb
# 3580aa21
# 28808903
# 46dedfa6
# 2e027dc1
# 0c7c4231
# 95981d1f
# 00c5ffb7
# be4ee537
# 8a0b74cc
# 4cdc3efa
# d20856aa
# b8170bba
# 9512c20b
# c38e2f28
# 14f65a5d
# 25b1b089
# d7c1fc0b
# 7caf609c
# 30436bfc
# ed10571d
# 0
# 32
# 3
# 5
#
# 1
# 0
# 0
# 61
# 5
# 0
# 1
# 3157
# 5
# e5f3fd8d
# a0aaffa6
# 6faa15d5
# da8a3421
# 3cd69f23
# 6fcd6dcb
# ab16ed81
# 43426c29
# 1df5e154
# 7de9c0a9
# 6652dc64
# 99eb4e27
# 00c5ffb7
# be4ee537
# f3bbfe99
# 4cdc3efa
# d20856aa
# a1eb1511
# 9512c20b
# febfd863
# a3323ca1
# c8e1ee56
# 1752e9e8
# 75350c8a
# 991321ea
# b757e957
# 0
#
# 233
# 1
# 146
# 1
# 0
# 0
# 99
# 7
# 0
# 1
# 3101
# 1
# 62770d79
# ad984203
# 62bec60d
# 386c49ee
# e755064d
# 6fcd6dcb
# b5f5eb62
# d1f2cc8b
# 2e4e821f
# 2e027dc1
# 0c7c4231
# 12716184
# 00c5ffb7
# be4ee537
# f70f0d0b
# 4cdc3efa
# d20856aa
# 628f1b8d
# 9512c20b
# c38e2f28
# 14f65a5d
# 25b1b089
# d7c1fc0b
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col 1   1000 non-null   object
#  1   Col 2   1000 non-null   object
#  2   Col 3   1000 non-null   object
#  3   Col 4   1000 non-null   object
#  4   Col 5   1000 non-null   object
#  5   Col 6   1000 non-null   object
#  6   Col 7   1000 non-null   object
#  7   Col 8   1000 non-null   object
#  8   Col 9   1000 non-null   object
#  9   Col 10  1000 non-null   object
#  10  Col 11  1000 non-null   object
#  11  Col 12  1000 non-null   object
#  12  Col 13  1000 non-null   object
#  13  Col 14  1000 non-null   object
#  14  Col 15  1000 non-null   object
#  15  Col 16  1000 non-null   object
#  16  Col 17  1000 non-null   object
#  17  Col 18  1000 non-null   object
#  18  Col 19  1000 non-null   object
#  19  Col 20  1000 non-null   object
#  20  Col 21  1000 non-null   object
# ...

# %%
df.describe()
# Out:
#        Col 1 Col 2 Col 3 Col 4 Col 5 Col 6 Col 7 Col 8 Col 9 Col 10  ...  \
# count   1000  1000  1000  1000  1000  1000  1000  1000  1000   1000  ...
# unique     2   111   554    45   195    84    24     7   250     50  ...
# top        0                                   0     0     1      0  ...
# freq     979   225    90   251   523   441   752   939   124    263  ...
#
#        Col 31    Col 32    Col 33    Col 34    Col 35    Col 36 Col 37  \
# count    1000      1000      1000      1000      1000      1000   1000
# unique      4        47        12       307       267       300    121
# top            b8170bba  9512c20b  156cbe87  96fbe197  15562d5d
# freq      461       512       431       374       374       374    461
#
#           Col 38    Col 39    Col 40
# count       1000      1000      1000
# unique       530        13        17
# top     16e6b497  30436bfc  e1be5ef2
# freq          26       524       368
#
# [4 rows x 40 columns]

# %%
df.head(10)
# Out:
#   Col 1 Col 2 Col 3 Col 4 Col 5 Col 6 Col 7 Col 8 Col 9 Col 10  ...    Col 31  \
# 0     1     5   110          16           1     0    14      7  ...  d20856aa
# 1     0    32     3     5           1     0     0    61      5  ...  d20856aa
# 2     0         233     1   146     1     0     0    99      7  ...  d20856aa
# 3     0          24          11    24           0    56      3  ...  1f7fc70b
# 4     0    60   223     6    15     5     0     0     1      8  ...  d20856aa
# 5     1     7     1    10     2           3     0     0     12  ...
# 6     0     1    52     1    59     9     0     0     1      1  ...
# 7     0    81   394     5           8     0     0    11     10  ...  753da5f3
# 8     0     1     3     0                 0     0  1748      5  ...  d20856aa
# 9     0     4    20     3     7     1     1     1     8      9  ...  d20856aa
#
#      Col 32    Col 33    Col 34    Col 35    Col 36    Col 37    Col 38  \
# ...

# %%
df.tail(10)
# Out:
#     Col 1 Col 2 Col 3 Col 4 Col 5 Col 6 Col 7 Col 8 Col 9 Col 10  ...  \
# 990     0         229                       0     0     1      1  ...
# 991     0   312    72    46   152    22     0     1    62      0  ...
# 992     0   282         110                 0     0     7      0  ...
# 993     0    13   217     9                 0     0     1      9  ...
# 994     0    22    11     9                 0     0    63      0  ...
# 995     0          15                             0   368      0  ...
# 996     0         922         207     7     0     0    -1      2  ...
# 997     0     8    48     2    70     1     0     0   105      2  ...
# 998     0    40   265    15          69     0     0    52      0  ...
# 999     0   133  4891     6                 0     0     0      9  ...
#
#        Col 31    Col 32    Col 33    Col 34    Col 35    Col 36    Col 37  \
# 990            b8170bba  9512c20b  8b800a58  0683bc6f  1600d91a
# ...

# %%
df.value_counts()
# Out:
# Col 1  Col 2  Col 3  Col 4  Col 5  Col 6  Col 7  Col 8  Col 9  Col 10  Col 11  Col 12  Col 13  Col 14  Col 15    Col 16    Col 17    Col 18    Col 19    Col 20    Col 21    Col 22    Col 23    Col 24    Col 25    Col 26    Col 27    Col 28    Col 29    Col 30    Col 31    Col 32    Col 33    Col 34    Col 35    Col 36    Col 37    Col 38    Col 39    Col 40
# 0                                                       -1     0                                       2a0c014f  278e06f2  10448b24  8b48388e  27d2607e  919c68e4  5e6216de  038e402d  2e4e821f  f5f09fe2  b59debeb  12716184  6397311a            46ccaa11                      a1eb1511  9512c20b  500bab44  1d43c72b  f104813b            b3116c88  30436bfc  2ccea557    1
# ...

# %%
df['Col 1'].value_counts()
# Out:
# 0    979
# 1     21
# Name: Col 1, dtype: int64

# %%
df['Col 2'].value_counts()
# Out:
#        225
# 1      117
# 2       90
# 3       61
# 4       39
#       ...
# 156      1
# 55       1
# 134      1
# 161      1
# 133      1
# Name: Col 2, Length: 111, dtype: int64

# %%
df.to_csv("criteo_thousand.csv", index=False)

# %%
df.hist(column = 'Col 2')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 df.hist(column = 'Col 2')
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:226, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     135 """
#     136 Make a histogram of the DataFrame's columns.
#     137
#    (...)
#     223     >>> hist = df.hist(bins=3)
#     224 """
#     225 plot_backend = _get_plot_backend(backend)
# --> 226 return plot_backend.hist_frame(
#     227     data,
#     228     column=column,
#     229     by=by,
#     230     grid=grid,
#     231     xlabelsize=xlabelsize,
#     232     xrot=xrot,
#     233     ylabelsize=ylabelsize,
#     234     yrot=yrot,
#     235     ax=ax,
#     236     sharex=sharex,
#     237     sharey=sharey,
# ...

# %%
df.dtypes
# Out:
# Col 1     object
# Col 2     object
# Col 3     object
# Col 4     object
# Col 5     object
# Col 6     object
# Col 7     object
# Col 8     object
# Col 9     object
# Col 10    object
# Col 11    object
# Col 12    object
# Col 13    object
# Col 14    object
# Col 15    object
# Col 16    object
# Col 17    object
# Col 18    object
# Col 19    object
# Col 20    object
# Col 21    object
# Col 22    object
# Col 23    object
# Col 24    object
# Col 25    object
# Col 26    object
# Col 27    object
# Col 28    object
# Col 29    object
# Col 30    object
# Col 31    object
# Col 32    object
# Col 33    object
# Col 34    object
# Col 35    object
# Col 36    object
# Col 37    object
# Col 38    object
# Col 39    object
# Col 40    object
# dtype: object

# %%
df = df.astype({'Col 1':'int'})
df = df.astype({'Col 9':'int'})
df = df.astype({'Col 10':'int'})

# %%
df.dtypes
# Out:
# Col 1       int32
# Col 2     float64
# Col 3      object
# Col 4      object
# Col 5      object
# Col 6      object
# Col 7      object
# Col 8      object
# Col 9       int32
# Col 10      int32
# Col 11     object
# Col 12     object
# Col 13     object
# Col 14     object
# Col 15     object
# Col 16     object
# Col 17     object
# Col 18     object
# Col 19     object
# Col 20     object
# Col 21     object
# Col 22     object
# Col 23     object
# Col 24     object
# Col 25     object
# Col 26     object
# Col 27     object
# Col 28     object
# Col 29     object
# Col 30     object
# Col 31     object
# Col 32     object
# Col 33     object
# Col 34     object
# Col 35     object
# Col 36     object
# Col 37     object
# Col 38     object
# Col 39     object
# Col 40     object
# dtype: object

# %%
df.hist('Col 1')
# Out:
# array([[<AxesSubplot:title={'center':'Col 1'}>]], dtype=object)

# %%
df.hist(column = 'Col 1', bins = 2)
# Out:
# array([[<AxesSubplot:title={'center':'Col 1'}>]], dtype=object)

# %%
df = df.astype({'Col 2':'int'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 df = df.astype({'Col 2':'int'})
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5898, in NDFrame.astype(self, dtype, copy, errors)
#    5896             res_col = col.copy() if copy else col
#    5897         else:
# -> 5898             res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    5899         results.append(res_col)
#    5901 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    5902     # GH 18099/22869: columnwise conversion to extension dtype
#    5903     # GH 24704: use iloc to handle duplicate column names
#    5904     # TODO(EA2D): special case not needed with 2D EAs
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
# ...

# %%
df = df.astype({'Col 3':'int'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 df = df.astype({'Col 3':'int'})
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5898, in NDFrame.astype(self, dtype, copy, errors)
#    5896             res_col = col.copy() if copy else col
#    5897         else:
# -> 5898             res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    5899         results.append(res_col)
#    5901 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    5902     # GH 18099/22869: columnwise conversion to extension dtype
#    5903     # GH 24704: use iloc to handle duplicate column names
#    5904     # TODO(EA2D): special case not needed with 2D EAs
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
# ...

# %%
df = df.astype({'Col 4':'int'})

# %%
df['Col 2'] = df['Col 2'].astype(str).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 df['Col 2'] = df['Col 2'].astype(str).astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df.dtypes
# Out:
# Col 1      int32
# Col 2     object
# Col 3     object
# Col 4     object
# Col 5     object
# Col 6     object
# Col 7     object
# Col 8     object
# Col 9     object
# Col 10    object
# Col 11    object
# Col 12    object
# Col 13    object
# Col 14    object
# Col 15    object
# Col 16    object
# Col 17    object
# Col 18    object
# Col 19    object
# Col 20    object
# Col 21    object
# Col 22    object
# Col 23    object
# Col 24    object
# Col 25    object
# Col 26    object
# Col 27    object
# Col 28    object
# Col 29    object
# Col 30    object
# Col 31    object
# Col 32    object
# Col 33    object
# Col 34    object
# Col 35    object
# Col 36    object
# Col 37    object
# Col 38    object
# Col 39    object
# Col 40    object
# dtype: object

# %%
df['Col 2']
# Out:
# 0        5
# 1       32
# 2
# 3
# 4       60
#       ...
# 995
# 996
# 997      8
# 998     40
# 999    133
# Name: Col 2, Length: 1000, dtype: object

# %%
df['Col 2'] = df['Col 2'].str.strip()

# %%
df = df.astype({'Col 2':'int'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 df = df.astype({'Col 2':'int'})
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5898, in NDFrame.astype(self, dtype, copy, errors)
#    5896             res_col = col.copy() if copy else col
#    5897         else:
# -> 5898             res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    5899         results.append(res_col)
#    5901 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    5902     # GH 18099/22869: columnwise conversion to extension dtype
#    5903     # GH 24704: use iloc to handle duplicate column names
#    5904     # TODO(EA2D): special case not needed with 2D EAs
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
# ...

# %%
df['Col 2'].isspace
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 df['Col 2'].isspace
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'isspace'

# %%
df.isnull().sum()
# Out:
# Col 1     0
# Col 2     0
# Col 3     0
# Col 4     0
# Col 5     0
# Col 6     0
# Col 7     0
# Col 8     0
# Col 9     0
# Col 10    0
# Col 11    0
# Col 12    0
# Col 13    0
# Col 14    0
# Col 15    0
# Col 16    0
# Col 17    0
# Col 18    0
# Col 19    0
# Col 20    0
# Col 21    0
# Col 22    0
# Col 23    0
# Col 24    0
# Col 25    0
# Col 26    0
# Col 27    0
# Col 28    0
# Col 29    0
# Col 30    0
# Col 31    0
# Col 32    0
# Col 33    0
# Col 34    0
# Col 35    0
# Col 36    0
# Col 37    0
# Col 38    0
# Col 39    0
# Col 40    0
# dtype: int64

# %%
df.isna()
# Out:
#      Col 1  Col 2  Col 3  Col 4  Col 5  Col 6  Col 7  Col 8  Col 9  Col 10  \
# 0    False  False  False  False  False  False  False  False  False   False
# 1    False  False  False  False  False  False  False  False  False   False
# 2    False  False  False  False  False  False  False  False  False   False
# 3    False  False  False  False  False  False  False  False  False   False
# 4    False  False  False  False  False  False  False  False  False   False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 995  False  False  False  False  False  False  False  False  False   False
# 996  False  False  False  False  False  False  False  False  False   False
# 997  False  False  False  False  False  False  False  False  False   False
# 998  False  False  False  False  False  False  False  False  False   False
# 999  False  False  False  False  False  False  False  False  False   False
#
# ...

# %%
for i in df['Col 2']:
    print(i)
# Out:
# 5
# 32
#
#
# 60
# 7
# 1
# 81
# 1
# 4
# 44
#
# 37
# 4
# 120
# 25
# 5
# 69
# 3
# 1
# 26
#
# 51
# 9
# 31
# 15
# 9
# 6
#
#
# 11
#
# 19
#
# 3
# 51
# 1
#
# 2
# 2
# 1
# 1
# 1
# 62
# 94
# 11
# 66
# 1
# 3
# 1
# 1
# 65
# 10
# 5
# 118
# 7
#
# 13
#
# 3
#
# 7
# 19
# 4
# 27
# 16
#
# 1
#
#
# 27
# 3
# 1
# 16
# 17
# 30
# 22
#
# 4
# 3
# 2
# 3
# 13
#
# 1
# 7
# 8
#
# 60
#
# 66
# 6
# 215
#
#
# 8
#
#
#
#
#
# 1
# 3
# 1
# 52
#
# 1
# 1
# 36
# 56
# 16
# 18
# 1
#
# 3
# 3
# 42
#
#
# 9
# 4
# 104
# 104
# 89
# 8
#
# 1
# 17
# 2
# 5
# 47
# 15
# 6
# 6
# 3
#
# 2
# 9
# 9
# 1
#
# 1
# 6
# 2
# 2
# 14
#
#
# 1
#
#
# 3
# 18
# 12
# 7
# 6
# 4
# 12
# 9
# 16
# 5
# 27
# 1
# 19
#
# 1
# 8
# 5
# 2
# 3
# 3
# 1
#
# 13
#
#
# 40
# 1
# 18
# 2
# 74
# 2
#
# 5
#
# 9
# 7
# 4
#
# 40
#
#
# 23
# 3
# 8
# 13
#
# 11
# 4
# 1
#
# 56
# 22
#
# 1
# 6
#
# 89
# 26
# 2
#
# 1
# 29
# 17
# 9
# 2
#
# 5
# 1
# 1
#
# 4
# 42
#
# 2
# 6
# 41
# 13
# 41
# 72
# 3
# 40
# 7
#
# 1
# 41
# 4
# 3
# 6
# 26
# 2
# 10
# 17
# 2
# 17
# 1
# 4
#
# 14
# 4
#
#
# 3
# 7
#
#
# 110
# 43
# ...

# %%
for i in df['Col 2']:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
for i in df['Col 2']:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
df['Col 2'] = pd. to_numeric(df['Col 2'])

# %%
df.dtypes
# Out:
# Col 1       int32
# Col 2     float64
# Col 3      object
# Col 4      object
# Col 5      object
# Col 6      object
# Col 7      object
# Col 8      object
# Col 9      object
# Col 10     object
# Col 11     object
# Col 12     object
# Col 13     object
# Col 14     object
# Col 15     object
# Col 16     object
# Col 17     object
# Col 18     object
# Col 19     object
# Col 20     object
# Col 21     object
# Col 22     object
# Col 23     object
# Col 24     object
# Col 25     object
# Col 26     object
# Col 27     object
# Col 28     object
# Col 29     object
# Col 30     object
# Col 31     object
# Col 32     object
# Col 33     object
# Col 34     object
# Col 35     object
# Col 36     object
# Col 37     object
# Col 38     object
# Col 39     object
# Col 40     object
# dtype: object

# %%
df = df.astype({'Col 2':'int'})
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 df = df.astype({'Col 2':'int'})
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5898, in NDFrame.astype(self, dtype, copy, errors)
#    5896             res_col = col.copy() if copy else col
#    5897         else:
# -> 5898             res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    5899         results.append(res_col)
#    5901 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    5902     # GH 18099/22869: columnwise conversion to extension dtype
#    5903     # GH 24704: use iloc to handle duplicate column names
#    5904     # TODO(EA2D): special case not needed with 2D EAs
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
# ...

# %%
df.hist(column = 'Col 2', bins = 2)

# %%
df['Col 2'].fillna(df['Col 2'].mean())
# Out:
# 0        5.000000
# 1       32.000000
# 2       29.757419
# 3       29.757419
# 4       60.000000
#           ...
# 995     29.757419
# 996     29.757419
# 997      8.000000
# 998     40.000000
# 999    133.000000
# Name: Col 2, Length: 1000, dtype: float64

# %%
df['Col 2'] = df['Col 2'].apply(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 df['Col 2'] = df['Col 2'].apply(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.dropna()
# Out:
#      Col 1  Col 2 Col 3 Col 4 Col 5 Col 6 Col 7 Col 8 Col 9 Col 10  ...  \
# 0        1    5.0   110          16           1     0    14      7  ...
# 1        0   32.0     3     5           1     0     0    61      5  ...
# 4        0   60.0   223     6    15     5     0     0     1      8  ...
# 5        1    7.0     1    10     2           3     0     0     12  ...
# 6        0    1.0    52     1    59     9     0     0     1      1  ...
# ..     ...    ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 993      0   13.0   217     9                 0     0     1      9  ...
# 994      0   22.0    11     9                 0     0    63      0  ...
# 997      0    8.0    48     2    70     1     0     0   105      2  ...
# 998      0   40.0   265    15          69     0     0    52      0  ...
# 999      0  133.0  4891     6                 0     0     0      9  ...
#
#        Col 31    Col 32    Col 33    Col 34    Col 35    Col 36    Col 37  \
# ...

# %%
df['Col 2'] = df['Col 2'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 df['Col 2'] = df['Col 2'].astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df.isnull().sum()
# Out:
# Col 1       0
# Col 2     225
# Col 3       0
# Col 4       0
# Col 5       0
# Col 6       0
# Col 7       0
# Col 8       0
# Col 9       0
# Col 10      0
# Col 11      0
# Col 12      0
# Col 13      0
# Col 14      0
# Col 15      0
# Col 16      0
# Col 17      0
# Col 18      0
# Col 19      0
# Col 20      0
# Col 21      0
# Col 22      0
# Col 23      0
# Col 24      0
# Col 25      0
# Col 26      0
# Col 27      0
# Col 28      0
# Col 29      0
# Col 30      0
# Col 31      0
# Col 32      0
# Col 33      0
# Col 34      0
# Col 35      0
# Col 36      0
# Col 37      0
# Col 38      0
# Col 39      0
# Col 40      0
# dtype: int64

# %%
df.head()
# Out:
#    Col 1  Col 2 Col 3 Col 4 Col 5 Col 6 Col 7 Col 8 Col 9 Col 10  ...  \
# 0      1    5.0   110          16           1     0    14      7  ...
# 1      0   32.0     3     5           1     0     0    61      5  ...
# 2      0    NaN   233     1   146     1     0     0    99      7  ...
# 3      0    NaN    24          11    24           0    56      3  ...
# 4      0   60.0   223     6    15     5     0     0     1      8  ...
#
#      Col 31    Col 32    Col 33    Col 34    Col 35    Col 36    Col 37  \
# 0  d20856aa  b8170bba  9512c20b  c38e2f28  14f65a5d  25b1b089  d7c1fc0b
# 1  d20856aa  a1eb1511  9512c20b  febfd863  a3323ca1  c8e1ee56  1752e9e8
# 2  d20856aa  628f1b8d  9512c20b  c38e2f28  14f65a5d  25b1b089  d7c1fc0b
# 3  1f7fc70b  a1eb1511  9512c20b                                dc209cd3
# 4  d20856aa  d9f758ff  9512c20b  c709ec07  2b07677e  a89a92a5  aa137169
#
#      Col 38    Col 39    Col 40
# 0  7caf609c  30436bfc  ed10571d
# 1  75350c8a  991321ea  b757e957
# ...

# %%
df['Col 3'] = df['Col 3'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 df['Col 3'] = df['Col 3'].astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df.dropna()
# Out:
#      Col 1  Col 2 Col 3 Col 4 Col 5 Col 6 Col 7 Col 8  Col 9  Col 10  ...  \
# 0        1    5.0   110          16           1     0     14       7  ...
# 1        0   32.0     3     5           1     0     0     61       5  ...
# 4        0   60.0   223     6    15     5     0     0      1       8  ...
# 5        1    7.0     1    10     2           3     0      0      12  ...
# 6        0    1.0    52     1    59     9     0     0      1       1  ...
# ..     ...    ...   ...   ...   ...   ...   ...   ...    ...     ...  ...
# 993      0   13.0   217     9                 0     0      1       9  ...
# 994      0   22.0    11     9                 0     0     63       0  ...
# 997      0    8.0    48     2    70     1     0     0    105       2  ...
# 998      0   40.0   265    15          69     0     0     52       0  ...
# 999      0  133.0  4891     6                 0     0      0       9  ...
#
#        Col 31    Col 32    Col 33    Col 34    Col 35    Col 36    Col 37  \
# ...

# %%
df.isnull().sum()
# Out:
# Col 1       0
# Col 2     225
# Col 3       0
# Col 4       0
# Col 5       0
# Col 6       0
# Col 7       0
# Col 8       0
# Col 9       0
# Col 10      0
# Col 11      0
# Col 12      0
# Col 13      0
# Col 14      0
# Col 15      0
# Col 16      0
# Col 17      0
# Col 18      0
# Col 19      0
# Col 20      0
# Col 21      0
# Col 22      0
# Col 23      0
# Col 24      0
# Col 25      0
# Col 26      0
# Col 27      0
# Col 28      0
# Col 29      0
# Col 30      0
# Col 31      0
# Col 32      0
# Col 33      0
# Col 34      0
# Col 35      0
# Col 36      0
# Col 37      0
# Col 38      0
# Col 39      0
# Col 40      0
# dtype: int64

# %%
df.head()
# Out:
#    Col 1  Col 2 Col 3 Col 4 Col 5 Col 6 Col 7 Col 8  Col 9  Col 10  ...  \
# 0      1    5.0   110          16           1     0     14       7  ...
# 1      0   32.0     3     5           1     0     0     61       5  ...
# 2      0    NaN   233     1   146     1     0     0     99       7  ...
# 3      0    NaN    24          11    24           0     56       3  ...
# 4      0   60.0   223     6    15     5     0     0      1       8  ...
#
#      Col 31    Col 32    Col 33    Col 34    Col 35    Col 36    Col 37  \
# 0  d20856aa  b8170bba  9512c20b  c38e2f28  14f65a5d  25b1b089  d7c1fc0b
# 1  d20856aa  a1eb1511  9512c20b  febfd863  a3323ca1  c8e1ee56  1752e9e8
# 2  d20856aa  628f1b8d  9512c20b  c38e2f28  14f65a5d  25b1b089  d7c1fc0b
# 3  1f7fc70b  a1eb1511  9512c20b                                dc209cd3
# 4  d20856aa  d9f758ff  9512c20b  c709ec07  2b07677e  a89a92a5  aa137169
#
#      Col 38    Col 39    Col 40
# 0  7caf609c  30436bfc  ed10571d
# 1  75350c8a  991321ea  b757e957
# ...

# %%
df1 = df.drop(['Col 2', 'Col 3', 'Col 4', 'Col 5', 'Col 6', 'Col 7', 'Col 8'], axis = 1)

# %%
df1.shape
# Out:
# (1000, 33)
